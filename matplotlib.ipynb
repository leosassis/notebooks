# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcdefaults()
mpl.rcParams['text.usetex'] = False
mpl.rcParams['mathtext.default'] = 'rm'
mpl.rcParams["mathtext.fontset"] = "dejavusans"  # or 'cm'

plt.plot([0, 1], [0, 1])
plt.title("E = mc^2")
plt.show()
