# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
#ML library.
import tensorflow
#Neural network library.
import keras

data = pd.read_csv("data/student-mat.csv", sep=";")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

#The label we wish to predict.
predict = "G3"

#Features/attributes.
X = np.array(data.drop([predict], axis=1))
#Labels/values to predict.
Y = np.array(data[predict])

#A subset of 10% of the data will be used for testing.
x_train, y_train, x_test, y_test = sklearn.model_selection.train_test_split(X, Y, test_size = 0.1)

# %%
print(data.head())
print(X)
print(Y)

print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4
# [[ 5  6  2  0  6]
#  [ 5  5  2  0  4]
#  [ 7  8  2  3 10]
#  ...
#  [10  8  1  3  3]
#  [11 12  1  0  0]
#  [ 8  9  1  0  5]]
# [ 6  6 10 15 10 15 11  6 19 15  9 12 14 11 16 14 14 10  5 10 15 15 16 12
#   8  8 11 15 11 11 12 17 16 12 15  6 18 15 11 13 11 12 18 11  9  6 11 20
#  14  7 13 13 10 11 13 10 15 15  9 16 11 11  9  9 10 15 12  6  8 16 15 10
#   5 14 11 10 10 11 10  5 12 11  6 15 10  8  6 14 10  7  8 18  6 10 14 10
#  15 10 14  8  5 17 14  6 18 11  8 18 13 16 19 10 13 19  9 16 14 13  8 13
#  15 15 13 13  8 12 11  9  0 18  0  0 12 11  0  0  0  0 12 15  0  9 11 13
#   0 11  0 11  0 10  0 14 10  0 12  8 13 10 15 12  0  7  0 10  7 12 10 16
#   0 14  0 16 10  0  9  9 11  6  9 11  8 12 17  8 12 11 11 15  9 10 13  9
#   8 10 14 15 16 10 18 10 16 10 10  6 11  9  7 13 10  7  8 13 14  8 10 15
#   4  8  8 10  6  0 17 13 14  7 15 12  9 12 14 11  9 13  6 10 13 12 11  0
#  12 12  0 12  0 18 13  8  5 15  8 10  8  8 12  8 13 11 14  0 18  8 12  9
#   0 17 10 11 10  0  9 14 11 14 10 12  9  9  8 10  8 10 12 10 11 11 19 12
#  14 15 11 15 13 18 14 11  0  8 14 16 11 10 14 18 13 12 18  8 12 10  0 13
#  11 11 13 11  0  9 10 11 13  9 11 15 15 11 16 10  9 14  8 14  0  0  0 15
#  13  0 17 10 11  0 15  0 10 14 16  9 15 13  8 13  8  8 11  9 13 11 10 16
#  13 12 10 15 12 10 13  0 10 11  9 12 11  5 19 10 15 10 15 10 14  7 10  0
#   5 10  6  0  8  0  9 16  7 10  9]
# [[13 13  2  0 23]
#  [12  0  3  2  0]
#  [12 10  2  0  2]
#  ...
#  [10 10  2  0  2]
#  [10 10  2  0  4]
#  [ 8  8  1  0  0]]
# [[ 7  9  2  0  0]
#  [11 11  1  0  0]
#  [16 18  2  0  0]
#  [10 11  2  0  2]
#  [10 11  1  0  8]
#  [ 7  8  4  0  8]
#  [14 15  2  0  0]
#  [18 16  3  0  0]
#  [ 6  5  1  0  7]
#  [15 13  2  0  9]
#  [ 6  6  2  2 22]
#  [15 16  1  0  4]
#  [15 14  3  2  4]
#  [ 9  9  2  0 56]
#  [ 9 10  2  0  2]
#  [12 13  2  0  0]
#  [18 18  4  0  6]
#  [ 7  7  3  0  0]
#  [ 6  6  2  1 13]
#  [13 13  2  0  2]
#  [ 8  8  2  0  0]
#  [13 14  1  0  0]
#  [ 8 12  1  0  0]
#  [10 11  4  0 10]
#  [16 14  4  0  6]
#  [14 15  1  0  3]
#  [ 7  7  4  0  4]
#  [15 14  2  0  4]
#  [12 12  1  0  8]
#  [10  9  4  0  0]
#  [ 5  5  2  0 12]
#  [ 6  5  2  0  6]
#  [10 13  1  0  4]
#  [ 7  6  1  1  0]
#  [12 12  1  0  2]
#  [16 16  1  0  0]
#  [ 7  7  2  3  5]
#  [ 6  5  1  3 16]
#  [14 14  3  0  4]
#  [10 10  3  2  8]]
# [13  0 11 11 11  0 17  9  7 16 11  8 11 11  6 14 10 16 12  9  0 18  8 15
#   8  9  0 10 12 13  6 15 11 14 13 13 14  8 10 14 11  0 11 12 10 13 12 10
#  16 11 11  8  9 16  8 12 15  8 10 19 16 12 15 13  9 11 12 13  8 10 11 10
#  11  9 13 10 10  8  6 11  8 17  0 18  6 18 16 10 19  9 11 10  8 12 14 11
#  13 10 13  8  9 10  9 15 15 10  7 10 13 10  6  0 14 13 13  8 18 18 14 13
#  14  7  7  7 13  6  9  5 11 11 13  5  0  0  0 15 11 12  9 10  8 15  8 18
#   8 11 19  8 15  9 18 10 10 10  0 11  0 17 11 11 10  0  6  0 11 15  0 10
#   7 14 11 15 15 15  9 15  8 11 13 13  8 12  9 15 10 11  8 20 15 13 14 10
#  16  6 13 15  9  0 17  8 18  5 10 14  6 11 12 10 11  9 12 14  8 10 15  9
#  11 12 12 16 10 10 14 10 12 11 10 13  0  0 10  6  8  9 10  9 15 12 12  5
#  12 12 13 13 12 11 13 10 14  8 14 12 14  7 10  0 12 10 10 15  9 16  0 13
#  14 12  0  0 11 16 10  8 10  9  0 15  0  6  9 18 13  7 15 10 12 12 15 11
#   0 17 14 10 12 18 13  0  9 15  0  9  0  9 15  0 15 10 12 16 10  0  6  0
#  11 14 14 15  0 10  9 16 11  0  0 10  8  0 17 11 16 18 12 11 16 19  8 10
#  11  9  5 10 11 11 10 14 14 11 13 10 13 10 13  9 11 10 11]
# [ 8 10 19 12 10  8 15 16  6 15  4 15 15  8 10 14 18  8  8 13  0 14 12 11
#  15 16  6 14 12  0  5  6 14  0 11 15  7  5 14 10]
